# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: colabgymrender==1.0.2 in /usr/local/lib/python3.10/dist-packages (1.0.2)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (3.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (1.0.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from colabgymrender==1.0.2) (4.8.0.76)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->colabgymrender==1.0.2) (0.0.8)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (4.66.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender==1.0.2) (0.5.1)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy->colabgymrender==1.0.2) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy->colabgymrender==1.0.2) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender==1.0.2) (2024.6.2)

# %%
from colabgymrender.recorder import Recorder
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/skimage/util/dtype.py:27: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   np.bool8: (False, True),
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/fx/painting.py:7: DeprecationWarning: Please use `sobel` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import sobel

# %%
# install dependencies
# !apt install chromium-browser xvfb
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-browser is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.10).
# 0 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.

# %%
env = gym.make('MountainCar-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -200.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
total_reward
# Out:
# -200.0

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 500000 # Increase max_num_steps
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 5e-4 # learning rate

memory_size = 500000
min_replay_size = 1000
batch_size = 32

target_update_frequency = 1000 # target network update frequency

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()

        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 64),
            nn.ReLU(),
            nn.Tanh(),
            # add more layer
            nn.Linear(64,128),
            nn.Tanh(),
            nn.Linear(128, env.action_space.n)
        )

    def forward(self, state):
        return self.network(state)

    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()

    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])

        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)

        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        reward_per_episode += reward

        state = next_state

        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0


        # Take a batch of experiences from the memory
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        # Compute targets using the formulation sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        # Compute loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        # gradient descent for q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        # print training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:<ipython-input-12-9a4e4dac0d4a>:44: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   states = torch.tensor(states, dtype=torch.float32)
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -200.0
# Episode: 50 Step: 10000 Average reward: -200.0
# Episode: 55 Step: 11000 Average reward: -200.0
# Episode: 60 Step: 12000 Average reward: -200.0
# Episode: 65 Step: 13000 Average reward: -200.0
# Episode: 70 Step: 14000 Average reward: -200.0
# Episode: 75 Step: 15000 Average reward: -200.0
# Episode: 80 Step: 16000 Average reward: -200.0
# Episode: 85 Step: 17000 Average reward: -200.0
# Episode: 90 Step: 18000 Average reward: -200.0
# Episode: 95 Step: 19000 Average reward: -200.0
# Episode: 100 Step: 20000 Average reward: -200.0
# Episode: 105 Step: 21000 Average reward: -200.0
# Episode: 110 Step: 22000 Average reward: -200.0
# Episode: 115 Step: 23000 Average reward: -200.0
# Episode: 120 Step: 24000 Average reward: -200.0
# Episode: 125 Step: 25000 Average reward: -200.0
# Episode: 130 Step: 26000 Average reward: -200.0
# Episode: 135 Step: 27000 Average reward: -200.0
# Episode: 140 Step: 28000 Average reward: -200.0
# Episode: 145 Step: 29000 Average reward: -200.0
# Episode: 150 Step: 30000 Average reward: -200.0
# Episode: 155 Step: 31000 Average reward: -200.0
# Episode: 160 Step: 32000 Average reward: -200.0
# Episode: 165 Step: 33000 Average reward: -200.0
# Episode: 170 Step: 34000 Average reward: -200.0
# Episode: 175 Step: 35000 Average reward: -200.0
# Episode: 180 Step: 36000 Average reward: -200.0
# Episode: 185 Step: 37000 Average reward: -200.0
# Episode: 190 Step: 38000 Average reward: -200.0
# Episode: 195 Step: 39000 Average reward: -200.0
# Episode: 200 Step: 40000 Average reward: -200.0
# Episode: 205 Step: 41000 Average reward: -200.0
# Episode: 210 Step: 42000 Average reward: -199.53
# Episode: 215 Step: 43000 Average reward: -199.53
# Episode: 220 Step: 44000 Average reward: -199.53
# Episode: 225 Step: 45000 Average reward: -199.53
# Episode: 230 Step: 46000 Average reward: -199.18
# Episode: 235 Step: 47000 Average reward: -199.18
# Episode: 240 Step: 48000 Average reward: -199.18
# Episode: 245 Step: 49000 Average reward: -199.18
# Episode: 250 Step: 50000 Average reward: -199.18
# Episode: 255 Step: 51000 Average reward: -199.18
# Episode: 260 Step: 52000 Average reward: -199.18
# Episode: 265 Step: 53000 Average reward: -199.18
# Episode: 270 Step: 54000 Average reward: -199.18
# Episode: 275 Step: 55000 Average reward: -199.18
# Episode: 280 Step: 56000 Average reward: -199.18
# Episode: 285 Step: 57000 Average reward: -199.18
# Episode: 290 Step: 58000 Average reward: -199.18
# Episode: 295 Step: 59000 Average reward: -199.08
# Episode: 300 Step: 60000 Average reward: -199.08
# Episode: 305 Step: 61000 Average reward: -199.08
# Episode: 310 Step: 62000 Average reward: -199.29
# Episode: 315 Step: 63000 Average reward: -199.29
# Episode: 320 Step: 64000 Average reward: -198.59
# Episode: 326 Step: 65000 Average reward: -198.68
# Episode: 331 Step: 66000 Average reward: -197.28
# Episode: 337 Step: 67000 Average reward: -196.39
# Episode: 342 Step: 68000 Average reward: -195.66
# Episode: 347 Step: 69000 Average reward: -195.66
# Episode: 352 Step: 70000 Average reward: -195.33
# Episode: 357 Step: 71000 Average reward: -195.33
# Episode: 362 Step: 72000 Average reward: -195.33
# Episode: 367 Step: 73000 Average reward: -195.33
# Episode: 372 Step: 74000 Average reward: -194.97
# Episode: 377 Step: 75000 Average reward: -194.84
# Episode: 383 Step: 76000 Average reward: -194.21
# Episode: 389 Step: 77000 Average reward: -192.67
# Episode: 394 Step: 78000 Average reward: -191.46
# Episode: 399 Step: 79000 Average reward: -191.46
# Episode: 405 Step: 80000 Average reward: -189.59
# Episode: 412 Step: 81000 Average reward: -186.98
# Episode: 418 Step: 82000 Average reward: -184.77
# Episode: 424 Step: 83000 Average reward: -183.73
# Episode: 431 Step: 84000 Average reward: -180.74
# Episode: 438 Step: 85000 Average reward: -178.4
# Episode: 446 Step: 86000 Average reward: -172.95
# Episode: 451 Step: 87000 Average reward: -172.52
# Episode: 458 Step: 88000 Average reward: -169.39
# Episode: 465 Step: 89000 Average reward: -165.03
# Episode: 471 Step: 90000 Average reward: -162.7
# Episode: 479 Step: 91000 Average reward: -157.9
# Episode: 485 Step: 92000 Average reward: -156.92
# Episode: 492 Step: 93000 Average reward: -153.74
# Episode: 499 Step: 94000 Average reward: -151.07
# Episode: 505 Step: 95000 Average reward: -150.08
# Episode: 511 Step: 96000 Average reward: -151.09
# Episode: 518 Step: 97000 Average reward: -149.59
# Episode: 526 Step: 98000 Average reward: -147.71
# Episode: 533 Step: 99000 Average reward: -146.6
# Episode: 540 Step: 100000 Average reward: -147.16
# Episode: 548 Step: 101000 Average reward: -146.07
# Episode: 554 Step: 102000 Average reward: -144.77
# Episode: 561 Step: 103000 Average reward: -143.61
# Episode: 567 Step: 104000 Average reward: -146.35
# Episode: 574 Step: 105000 Average reward: -146.38
# Episode: 580 Step: 106000 Average reward: -147.81
# Episode: 586 Step: 107000 Average reward: -148.5
# Episode: 593 Step: 108000 Average reward: -147.7
# Episode: 600 Step: 109000 Average reward: -148.54
# Episode: 606 Step: 110000 Average reward: -149.25
# Episode: 613 Step: 111000 Average reward: -147.96
# Episode: 620 Step: 112000 Average reward: -148.63
# Episode: 626 Step: 113000 Average reward: -149.37
# Episode: 634 Step: 114000 Average reward: -149.68
# Episode: 640 Step: 115000 Average reward: -149.09
# Episode: 648 Step: 116000 Average reward: -149.9
# Episode: 654 Step: 117000 Average reward: -150.29
# Episode: 661 Step: 118000 Average reward: -150.02
# Episode: 667 Step: 119000 Average reward: -149.68
# Episode: 675 Step: 120000 Average reward: -147.48
# Episode: 682 Step: 121000 Average reward: -147.05
# Episode: 690 Step: 122000 Average reward: -145.21
# Episode: 697 Step: 123000 Average reward: -143.99
# Episode: 704 Step: 124000 Average reward: -142.31
# Episode: 713 Step: 125000 Average reward: -140.2
# Episode: 721 Step: 126000 Average reward: -138.83
# Episode: 729 Step: 127000 Average reward: -137.51
# Episode: 737 Step: 128000 Average reward: -135.26
# Episode: 744 Step: 129000 Average reward: -135.2
# Episode: 751 Step: 130000 Average reward: -134.67
# Episode: 758 Step: 131000 Average reward: -133.94
# Episode: 765 Step: 132000 Average reward: -134.12
# Episode: 773 Step: 133000 Average reward: -132.28
# Episode: 781 Step: 134000 Average reward: -132.08
# Episode: 789 Step: 135000 Average reward: -131.13
# Episode: 797 Step: 136000 Average reward: -130.52
# Episode: 805 Step: 137000 Average reward: -128.94
# Episode: 812 Step: 138000 Average reward: -129.97
# Episode: 820 Step: 139000 Average reward: -130.43
# Episode: 828 Step: 140000 Average reward: -130.8
# Episode: 836 Step: 141000 Average reward: -131.18
# Episode: 843 Step: 142000 Average reward: -130.71
# Episode: 851 Step: 143000 Average reward: -131.24
# Episode: 858 Step: 144000 Average reward: -130.28
# Episode: 865 Step: 145000 Average reward: -129.75
# Episode: 872 Step: 146000 Average reward: -131.42
# Episode: 879 Step: 147000 Average reward: -131.55
# Episode: 888 Step: 148000 Average reward: -131.06
# Episode: 896 Step: 149000 Average reward: -131.3
# Episode: 904 Step: 150000 Average reward: -132.02
# Episode: 911 Step: 151000 Average reward: -131.56
# Episode: 919 Step: 152000 Average reward: -131.94
# Episode: 926 Step: 153000 Average reward: -132.13
# Episode: 933 Step: 154000 Average reward: -134.01
# Episode: 939 Step: 155000 Average reward: -135.88
# Episode: 946 Step: 156000 Average reward: -136.48
# Episode: 953 Step: 157000 Average reward: -136.77
# Episode: 960 Step: 158000 Average reward: -138.58
# Episode: 967 Step: 159000 Average reward: -137.84
# Episode: 975 Step: 160000 Average reward: -136.05
# Episode: 981 Step: 161000 Average reward: -138.32
# Episode: 989 Step: 162000 Average reward: -139.27
# Episode: 996 Step: 163000 Average reward: -140.13
# Episode: 1004 Step: 164000 Average reward: -139.87
# Episode: 1012 Step: 165000 Average reward: -139.79
# Episode: 1019 Step: 166000 Average reward: -139.11
# Episode: 1027 Step: 167000 Average reward: -138.92
# Episode: 1034 Step: 168000 Average reward: -137.74
# Episode: 1041 Step: 169000 Average reward: -136.75
# Episode: 1049 Step: 170000 Average reward: -135.23
# Episode: 1057 Step: 171000 Average reward: -134.3
# Episode: 1064 Step: 172000 Average reward: -133.97
# Episode: 1072 Step: 173000 Average reward: -134.25
# Episode: 1079 Step: 174000 Average reward: -133.58
# Episode: 1085 Step: 175000 Average reward: -134.23
# Episode: 1093 Step: 176000 Average reward: -133.73
# Episode: 1101 Step: 177000 Average reward: -134.03
# Episode: 1107 Step: 178000 Average reward: -134.52
# Episode: 1115 Step: 179000 Average reward: -134.45
# Episode: 1122 Step: 180000 Average reward: -135.84
# Episode: 1131 Step: 181000 Average reward: -133.42
# Episode: 1140 Step: 182000 Average reward: -132.04
# Episode: 1146 Step: 183000 Average reward: -133.73
# Episode: 1154 Step: 184000 Average reward: -134.37
# Episode: 1161 Step: 185000 Average reward: -134.06
# Episode: 1168 Step: 186000 Average reward: -134.55
# Episode: 1175 Step: 187000 Average reward: -134.27
# Episode: 1183 Step: 188000 Average reward: -134.25
# Episode: 1190 Step: 189000 Average reward: -133.63
# Episode: 1198 Step: 190000 Average reward: -134.59
# Episode: 1206 Step: 191000 Average reward: -132.06
# Episode: 1213 Step: 192000 Average reward: -131.8
# Episode: 1222 Step: 193000 Average reward: -131.33
# Episode: 1228 Step: 194000 Average reward: -132.99
# Episode: 1236 Step: 195000 Average reward: -134.65
# Episode: 1243 Step: 196000 Average reward: -134.33
# Episode: 1250 Step: 197000 Average reward: -135.3
# Episode: 1258 Step: 198000 Average reward: -133.86
# Episode: 1264 Step: 199000 Average reward: -135.99
# Episode: 1272 Step: 200000 Average reward: -134.79
# Episode: 1279 Step: 201000 Average reward: -133.91
# Episode: 1286 Step: 202000 Average reward: -135.76
# Episode: 1293 Step: 203000 Average reward: -135.43
# Episode: 1300 Step: 204000 Average reward: -136.41
# Episode: 1308 Step: 205000 Average reward: -138.0
# Episode: 1315 Step: 206000 Average reward: -137.16
# Episode: 1322 Step: 207000 Average reward: -139.08
# Episode: 1329 Step: 208000 Average reward: -138.26
# Episode: 1336 Step: 209000 Average reward: -139.1
# Episode: 1345 Step: 210000 Average reward: -137.55
# Episode: 1353 Step: 211000 Average reward: -136.21
# Episode: 1360 Step: 212000 Average reward: -136.07
# Episode: 1368 Step: 213000 Average reward: -134.57
# Episode: 1375 Step: 214000 Average reward: -135.85
# Episode: 1383 Step: 215000 Average reward: -135.13
# Episode: 1391 Step: 216000 Average reward: -133.65
# Episode: 1399 Step: 217000 Average reward: -130.92
# Episode: 1407 Step: 218000 Average reward: -131.35
# Episode: 1417 Step: 219000 Average reward: -127.74
# Episode: 1426 Step: 220000 Average reward: -125.29
# Episode: 1434 Step: 221000 Average reward: -122.89
# Episode: 1442 Step: 222000 Average reward: -123.42
# Episode: 1449 Step: 223000 Average reward: -124.7
# Episode: 1457 Step: 224000 Average reward: -123.52
# Episode: 1466 Step: 225000 Average reward: -122.49
# Episode: 1474 Step: 226000 Average reward: -121.65
# Episode: 1482 Step: 227000 Average reward: -120.34
# Episode: 1490 Step: 228000 Average reward: -121.43
# Episode: 1498 Step: 229000 Average reward: -122.3
# Episode: 1506 Step: 230000 Average reward: -120.96
# Episode: 1513 Step: 231000 Average reward: -123.96
# Episode: 1520 Step: 232000 Average reward: -126.22
# Episode: 1526 Step: 233000 Average reward: -129.32
# Episode: 1533 Step: 234000 Average reward: -131.24
# Episode: 1539 Step: 235000 Average reward: -134.45
# Episode: 1546 Step: 236000 Average reward: -134.25
# Episode: 1553 Step: 237000 Average reward: -134.51
# Episode: 1560 Step: 238000 Average reward: -136.07
# Episode: 1567 Step: 239000 Average reward: -138.75
# Episode: 1575 Step: 240000 Average reward: -139.01
# Episode: 1583 Step: 241000 Average reward: -139.46
# Episode: 1590 Step: 242000 Average reward: -139.83
# Episode: 1598 Step: 243000 Average reward: -139.98
# Episode: 1605 Step: 244000 Average reward: -141.67
# Episode: 1612 Step: 245000 Average reward: -140.37
# Episode: 1619 Step: 246000 Average reward: -140.92
# Episode: 1626 Step: 247000 Average reward: -140.23
# Episode: 1634 Step: 248000 Average reward: -137.66
# Episode: 1641 Step: 249000 Average reward: -136.51
# Episode: 1649 Step: 250000 Average reward: -135.94
# Episode: 1657 Step: 251000 Average reward: -135.52
# Episode: 1665 Step: 252000 Average reward: -133.93
# Episode: 1673 Step: 253000 Average reward: -132.09
# Episode: 1681 Step: 254000 Average reward: -132.08
# Episode: 1690 Step: 255000 Average reward: -130.24
# Episode: 1698 Step: 256000 Average reward: -129.04
# Episode: 1706 Step: 257000 Average reward: -127.1
# Episode: 1714 Step: 258000 Average reward: -127.74
# Episode: 1723 Step: 259000 Average reward: -124.88
# Episode: 1731 Step: 260000 Average reward: -123.4
# Episode: 1739 Step: 261000 Average reward: -124.28
# Episode: 1746 Step: 262000 Average reward: -123.65
# Episode: 1754 Step: 263000 Average reward: -123.84
# Episode: 1761 Step: 264000 Average reward: -124.72
# Episode: 1770 Step: 265000 Average reward: -123.74
# Episode: 1777 Step: 266000 Average reward: -124.3
# Episode: 1784 Step: 267000 Average reward: -125.86
# Episode: 1793 Step: 268000 Average reward: -125.63
# Episode: 1801 Step: 269000 Average reward: -126.74
# Episode: 1808 Step: 270000 Average reward: -128.11
# Episode: 1816 Step: 271000 Average reward: -127.99
# Episode: 1823 Step: 272000 Average reward: -129.56
# Episode: 1831 Step: 273000 Average reward: -130.63
# Episode: 1840 Step: 274000 Average reward: -127.94
# Episode: 1848 Step: 275000 Average reward: -127.7
# Episode: 1855 Step: 276000 Average reward: -127.86
# Episode: 1862 Step: 277000 Average reward: -128.08
# Episode: 1870 Step: 278000 Average reward: -130.29
# Episode: 1877 Step: 279000 Average reward: -130.76
# Episode: 1884 Step: 280000 Average reward: -129.92
# Episode: 1892 Step: 281000 Average reward: -130.92
# Episode: 1900 Step: 282000 Average reward: -131.0
# Episode: 1909 Step: 283000 Average reward: -128.61
# Episode: 1918 Step: 284000 Average reward: -127.83
# Episode: 1927 Step: 285000 Average reward: -124.72
# Episode: 1935 Step: 286000 Average reward: -125.29
# Episode: 1943 Step: 287000 Average reward: -126.6
# Episode: 1950 Step: 288000 Average reward: -127.86
# Episode: 1958 Step: 289000 Average reward: -125.66
# Episode: 1967 Step: 290000 Average reward: -123.19
# Episode: 1975 Step: 291000 Average reward: -122.98
# Episode: 1984 Step: 292000 Average reward: -120.9
# Episode: 1993 Step: 293000 Average reward: -119.01
# Episode: 2001 Step: 294000 Average reward: -119.16
# Episode: 2010 Step: 295000 Average reward: -118.9
# Episode: 2019 Step: 296000 Average reward: -118.94
# Episode: 2028 Step: 297000 Average reward: -117.36
# Episode: 2037 Step: 298000 Average reward: -117.5
# Episode: 2046 Step: 299000 Average reward: -116.05
# Episode: 2056 Step: 300000 Average reward: -113.06
# Episode: 2064 Step: 301000 Average reward: -113.54
# Episode: 2073 Step: 302000 Average reward: -112.72
# Episode: 2082 Step: 303000 Average reward: -112.53
# Episode: 2091 Step: 304000 Average reward: -112.2
# Episode: 2101 Step: 305000 Average reward: -110.7
# Episode: 2110 Step: 306000 Average reward: -110.91
# Episode: 2119 Step: 307000 Average reward: -109.9
# Episode: 2127 Step: 308000 Average reward: -111.01
# Episode: 2136 Step: 309000 Average reward: -109.96
# Episode: 2145 Step: 310000 Average reward: -110.84
# Episode: 2154 Step: 311000 Average reward: -111.76
# Episode: 2162 Step: 312000 Average reward: -111.52
# Episode: 2172 Step: 313000 Average reward: -111.26
# Episode: 2180 Step: 314000 Average reward: -112.36
# Episode: 2189 Step: 315000 Average reward: -112.46
# Episode: 2197 Step: 316000 Average reward: -113.85
# Episode: 2206 Step: 317000 Average reward: -113.48
# Episode: 2214 Step: 318000 Average reward: -115.76
# Episode: 2222 Step: 319000 Average reward: -116.26
# Episode: 2231 Step: 320000 Average reward: -115.44
# Episode: 2240 Step: 321000 Average reward: -115.2
# Episode: 2250 Step: 322000 Average reward: -114.1
# Episode: 2259 Step: 323000 Average reward: -113.81
# Episode: 2268 Step: 324000 Average reward: -113.4
# Episode: 2278 Step: 325000 Average reward: -112.47
# Episode: 2288 Step: 326000 Average reward: -111.18
# Episode: 2297 Step: 327000 Average reward: -110.34
# Episode: 2306 Step: 328000 Average reward: -109.96
# Episode: 2314 Step: 329000 Average reward: -109.67
# Episode: 2322 Step: 330000 Average reward: -109.8
# Episode: 2332 Step: 331000 Average reward: -109.34
# Episode: 2341 Step: 332000 Average reward: -109.48
# Episode: 2350 Step: 333000 Average reward: -110.0
# Episode: 2359 Step: 334000 Average reward: -110.02
# Episode: 2368 Step: 335000 Average reward: -110.27
# Episode: 2377 Step: 336000 Average reward: -111.47
# Episode: 2386 Step: 337000 Average reward: -111.81
# Episode: 2394 Step: 338000 Average reward: -112.6
# Episode: 2403 Step: 339000 Average reward: -113.83
# Episode: 2412 Step: 340000 Average reward: -113.7
# Episode: 2421 Step: 341000 Average reward: -112.13
# Episode: 2429 Step: 342000 Average reward: -112.97
# Episode: 2439 Step: 343000 Average reward: -112.31
# Episode: 2447 Step: 344000 Average reward: -112.37
# Episode: 2456 Step: 345000 Average reward: -112.29
# Episode: 2465 Step: 346000 Average reward: -113.41
# Episode: 2473 Step: 347000 Average reward: -114.47
# Episode: 2481 Step: 348000 Average reward: -114.91
# Episode: 2490 Step: 349000 Average reward: -114.67
# Episode: 2499 Step: 350000 Average reward: -114.73
# Episode: 2508 Step: 351000 Average reward: -114.55
# Episode: 2516 Step: 352000 Average reward: -115.33
# Episode: 2525 Step: 353000 Average reward: -114.79
# Episode: 2534 Step: 354000 Average reward: -114.31
# Episode: 2543 Step: 355000 Average reward: -115.15
# Episode: 2551 Step: 356000 Average reward: -115.45
# Episode: 2560 Step: 357000 Average reward: -115.57
# Episode: 2569 Step: 358000 Average reward: -115.42
# Episode: 2578 Step: 359000 Average reward: -114.57
# Episode: 2586 Step: 360000 Average reward: -114.85
# Episode: 2594 Step: 361000 Average reward: -115.48
# Episode: 2602 Step: 362000 Average reward: -116.11
# Episode: 2610 Step: 363000 Average reward: -116.77
# Episode: 2619 Step: 364000 Average reward: -116.71
# Episode: 2628 Step: 365000 Average reward: -117.24
# Episode: 2636 Step: 366000 Average reward: -117.27
# Episode: 2645 Step: 367000 Average reward: -117.47
# Episode: 2654 Step: 368000 Average reward: -117.08
# Episode: 2663 Step: 369000 Average reward: -116.68
# Episode: 2671 Step: 370000 Average reward: -116.58
# Episode: 2680 Step: 371000 Average reward: -117.14
# Episode: 2688 Step: 372000 Average reward: -116.78
# Episode: 2697 Step: 373000 Average reward: -115.35
# Episode: 2706 Step: 374000 Average reward: -115.14
# Episode: 2715 Step: 375000 Average reward: -114.07
# Episode: 2724 Step: 376000 Average reward: -113.65
# Episode: 2733 Step: 377000 Average reward: -113.66
# Episode: 2742 Step: 378000 Average reward: -113.33
# Episode: 2751 Step: 379000 Average reward: -113.15
# Episode: 2759 Step: 380000 Average reward: -113.83
# Episode: 2768 Step: 381000 Average reward: -113.75
# Episode: 2776 Step: 382000 Average reward: -114.55
# Episode: 2783 Step: 383000 Average reward: -115.86
# Episode: 2792 Step: 384000 Average reward: -115.99
# Episode: 2800 Step: 385000 Average reward: -116.92
# Episode: 2808 Step: 386000 Average reward: -117.77
# Episode: 2817 Step: 387000 Average reward: -118.81
# Episode: 2825 Step: 388000 Average reward: -119.86
# Episode: 2833 Step: 389000 Average reward: -120.89
# Episode: 2841 Step: 390000 Average reward: -120.66
# Episode: 2850 Step: 391000 Average reward: -120.53
# Episode: 2859 Step: 392000 Average reward: -119.37
# Episode: 2868 Step: 393000 Average reward: -121.27
# Episode: 2876 Step: 394000 Average reward: -119.57
# Episode: 2883 Step: 395000 Average reward: -120.86
# Episode: 2891 Step: 396000 Average reward: -121.47
# Episode: 2900 Step: 397000 Average reward: -120.4
# Episode: 2908 Step: 398000 Average reward: -120.64
# Episode: 2916 Step: 399000 Average reward: -120.64
# Episode: 2925 Step: 400000 Average reward: -119.75
# Episode: 2934 Step: 401000 Average reward: -118.36
# Episode: 2942 Step: 402000 Average reward: -119.24
# Episode: 2951 Step: 403000 Average reward: -119.49
# Episode: 2959 Step: 404000 Average reward: -121.1
# Episode: 2967 Step: 405000 Average reward: -121.06
# Episode: 2974 Step: 406000 Average reward: -122.02
# Episode: 2983 Step: 407000 Average reward: -119.35
# Episode: 2992 Step: 408000 Average reward: -118.9
# Episode: 3000 Step: 409000 Average reward: -120.06
# Episode: 3008 Step: 410000 Average reward: -119.84
# Episode: 3018 Step: 411000 Average reward: -117.72
# Episode: 3026 Step: 412000 Average reward: -118.52
# Episode: 3036 Step: 413000 Average reward: -118.28
# Episode: 3045 Step: 414000 Average reward: -116.82
# Episode: 3053 Step: 415000 Average reward: -117.48
# Episode: 3062 Step: 416000 Average reward: -116.21
# Episode: 3070 Step: 417000 Average reward: -115.15
# Episode: 3079 Step: 418000 Average reward: -114.3
# Episode: 3088 Step: 419000 Average reward: -114.79
# Episode: 3097 Step: 420000 Average reward: -113.16
# Episode: 3106 Step: 421000 Average reward: -112.75
# Episode: 3114 Step: 422000 Average reward: -113.78
# Episode: 3123 Step: 423000 Average reward: -113.67
# Episode: 3132 Step: 424000 Average reward: -113.57
# Episode: 3142 Step: 425000 Average reward: -113.38
# Episode: 3151 Step: 426000 Average reward: -112.77
# Episode: 3160 Step: 427000 Average reward: -111.75
# Episode: 3169 Step: 428000 Average reward: -111.95
# Episode: 3177 Step: 429000 Average reward: -112.1
# Episode: 3186 Step: 430000 Average reward: -111.99
# Episode: 3196 Step: 431000 Average reward: -111.51
# Episode: 3205 Step: 432000 Average reward: -111.49
# Episode: 3214 Step: 433000 Average reward: -109.92
# Episode: 3223 Step: 434000 Average reward: -110.5
# Episode: 3231 Step: 435000 Average reward: -110.98
# Episode: 3240 Step: 436000 Average reward: -112.26
# Episode: 3248 Step: 437000 Average reward: -112.69
# Episode: 3255 Step: 438000 Average reward: -115.01
# Episode: 3263 Step: 439000 Average reward: -116.5
# Episode: 3272 Step: 440000 Average reward: -116.19
# Episode: 3280 Step: 441000 Average reward: -116.77
# Episode: 3288 Step: 442000 Average reward: -118.24
# Episode: 3296 Step: 443000 Average reward: -119.13
# Episode: 3304 Step: 444000 Average reward: -119.95
# Episode: 3314 Step: 445000 Average reward: -120.2
# Episode: 3321 Step: 446000 Average reward: -120.53
# Episode: 3329 Step: 447000 Average reward: -122.3
# Episode: 3338 Step: 448000 Average reward: -122.53
# Episode: 3347 Step: 449000 Average reward: -121.63
# Episode: 3353 Step: 450000 Average reward: -123.0
# Episode: 3362 Step: 451000 Average reward: -121.88
# Episode: 3371 Step: 452000 Average reward: -121.65
# Episode: 3379 Step: 453000 Average reward: -120.56
# Episode: 3388 Step: 454000 Average reward: -119.57
# Episode: 3396 Step: 455000 Average reward: -120.16
# Episode: 3406 Step: 456000 Average reward: -118.44
# Episode: 3414 Step: 457000 Average reward: -119.42
# Episode: 3423 Step: 458000 Average reward: -118.48
# Episode: 3432 Step: 459000 Average reward: -116.53
# Episode: 3440 Step: 460000 Average reward: -117.22
# Episode: 3449 Step: 461000 Average reward: -117.26
# Episode: 3457 Step: 462000 Average reward: -115.56
# Episode: 3467 Step: 463000 Average reward: -114.9
# Episode: 3475 Step: 464000 Average reward: -114.83
# Episode: 3484 Step: 465000 Average reward: -114.31
# Episode: 3492 Step: 466000 Average reward: -116.0
# Episode: 3501 Step: 467000 Average reward: -114.83
# Episode: 3510 Step: 468000 Average reward: -116.5
# Episode: 3519 Step: 469000 Average reward: -114.44
# Episode: 3528 Step: 470000 Average reward: -114.29
# Episode: 3538 Step: 471000 Average reward: -112.18
# Episode: 3547 Step: 472000 Average reward: -112.63
# Episode: 3555 Step: 473000 Average reward: -111.84
# Episode: 3563 Step: 474000 Average reward: -113.24
# Episode: 3572 Step: 475000 Average reward: -113.54
# Episode: 3581 Step: 476000 Average reward: -113.25
# Episode: 3590 Step: 477000 Average reward: -113.21
# Episode: 3599 Step: 478000 Average reward: -112.55
# Episode: 3607 Step: 479000 Average reward: -112.92
# Episode: 3617 Step: 480000 Average reward: -112.2
# Episode: 3626 Step: 481000 Average reward: -112.05
# Episode: 3635 Step: 482000 Average reward: -113.44
# Episode: 3644 Step: 483000 Average reward: -113.21
# Episode: 3652 Step: 484000 Average reward: -113.26
# Episode: 3661 Step: 485000 Average reward: -112.79
# Episode: 3669 Step: 486000 Average reward: -112.99
# Episode: 3678 Step: 487000 Average reward: -113.82
# Episode: 3687 Step: 488000 Average reward: -113.55
# Episode: 3695 Step: 489000 Average reward: -114.26
# Episode: 3704 Step: 490000 Average reward: -113.89
# Episode: 3713 Step: 491000 Average reward: -113.75
# Episode: 3721 Step: 492000 Average reward: -115.11
# Episode: 3730 Step: 493000 Average reward: -115.25
# Episode: 3739 Step: 494000 Average reward: -115.96
# Episode: 3747 Step: 495000 Average reward: -116.17
# Episode: 3755 Step: 496000 Average reward: -116.21
# Episode: 3764 Step: 497000 Average reward: -116.43
# Episode: 3773 Step: 498000 Average reward: -116.12
# Episode: 3781 Step: 499000 Average reward: -115.88
# Episode: 3790 Step: 500000 Average reward: -116.19

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# -83.0
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# Những thứ thay đổi:
#
# HyperParameter: tăng max_num_steps = 500000, tăng memory_size =  500000
#
# Mạng neural: thêm một neural network size 128 và xài thêm mạng nn.RLU()
